# %%
import aa_fibers
from aa_fibers import antigen2HFalleleE
from aa_fibers import getAAgenostringmatchFIBERSE
# Out:
# MSF files already downloaded
# MSF files already downloaded
# MSF files already downloaded
# MSF files already downloaded
# MSF files already downloaded
# MSF files already downloaded
# MSF files already downloaded
# MSF files already downloaded
# MSF files already downloaded

# %%
#E functions to show enumeration of AA-MM probabilities
#Only difference from normal functions are the print statements and probabilities being calculated inside of the getAAgenostringmatchE function

dalldr1,dfdr1,dnalldr1,ddr1sumant,ddr1allelefreqs,d1prob,ddr1alleles  = antigen2HFalleleE("AFA","DR3")
dalldr2,dfdr2,dnalldr2, ddr2sumant,ddr2allelefreqs, d2prob,ddr2alleles = antigen2HFalleleE("AFA","DR3")


#Showing functions to process D|R from antigen to list of alleles, nested inside of high freq allele function
#def antigen2allele(antigen):
# 	#print(antigen)
# 	anti_filename = "/Users/gracelord/dev/hlamatchit/hlamatchit_home/OPTN_antigens_to_alleles_CPRA.txt"
# 	antifile = open(anti_filename, "r")
# 	antigen_allele_list = {}
# 	for row in antifile:
# 		row=row.rstrip()
# 		#print(antigen)
# 		if antigen in row:
# 			(antigen,alleles_gl) = row.split("\t")
# 			# change list of alleles in GL string to comma-delimited
# 			allele_list = alleles_gl.split("/")
# 			antigen_allele_list[antigen] = ",".join(allele_list)
# 		else:
# 			continue
# 	#print(antigen)
# 	#print(allele_list)
# 	alleles = allele_list

# 	#print(alleles)
# 	return alleles


#Function returns fres of all alleles and the most probable allele

# def antigen2HFalleleE(race,antigen):
# 	alleles = antigen2allele(antigen)
# 	print( "Race:", race, "antigen:", antigen)
# 	print("Alleles from OPTN selected by antigen2allele function:", alleles[:5])
# 	#print(alleles)
# 	possible_alleles = defaultdict(dict)
# 	for allele in alleles:
# 		#print(allele)
# 		possible = highfreq(race,allele)
# 		if allele not in possible_alleles:
# 			possible_alleles[allele]=possible
# 		else:
# 			continue
# 	#print("Possible Alleles with Population Frequencies from NMDP selected by highfreq function:", possible_alleles)
# 	max_freq = max(possible_alleles.values())
# 	max_allele = max(possible_alleles, key=possible_alleles.get)
# 	alleles = {x:y for x,y in possible_alleles.items() if y!=0}
# 	nalleles = len(alleles)
# 	sumant =sum(possible_alleles.values())
# 	#print("Only Alleles with frequency in Genetic Reference Population:", alleles)
# 	print("Sum of Allele Frequencies for Probability Calcs:", sumant)
# 	print( "Most probable Allele and its Frequency:", max_allele, max_freq)
# 	allelefreqs = probcheck(alleles, sumant)
# 	print("Prob check function calculating Allele level Probs using AlleleFreq/AntigenFreq for every possible Allele:", allelefreqs)
# 	prob = max_freq/sumant
# 	print("Most Probable Alleles Probability:", prob)
# 	return max_allele, max_freq, nalleles, sumant, allelefreqs, prob, alleles

    
ralldr1,rfdr1,rnalldr1,rdr1sumant,rdr1allelefreqs,r1prob,rdr1alleles = antigen2HFalleleE("CAU","DR2")
ralldr2,rfdr2,rnalldr2,rdr2sumant,rdr2allelefreqs,r2prob,rdr2alleles = antigen2HFalleleE("CAU","DR2")
# Out:
# Race: AFA antigen: DR6
00037368023101961255, 'DRB1*14:19', 7.175336295650317e-06, 'DRB1*14:20', 5.877886862133642e-05, 'DRB1*14:21', 3.0873422109535755e-05, 'DRB1*14:23', 1.324804227133685e-05, 'DRB1*14:24', 1.1319915747734585e-05, 'DRB1*14:25', 3.063670272897568e-06, 'DRB1*14:27', 5.998066842226115e-07, 'DRB1*14:33', 4.798453535906817e-06, 'DRB1*14:47', 3.020109785057235e-06, 'DRB1*14:70', 1.9779540339692066e-05]
# Most Probable Alleles Probability: 0.396623226990731

# %%
#Pass through the dictionary of all possible alleles in the reference genetic population and their frequencies
#Test all D|R combos to see which ones MM and then calculate the probability of MM


# def getAAgenostringmatchFIBERSE(dalleles1, dalleles2, ralleles1, ralleles2, locus):

# 	#To calculate AA-MM pos probs
# 	aa_geno_recip = defaultdict(dict)
# 	aa_geno_donor = defaultdict(dict)
# 	aa_prob_recip = defaultdict(dict)
# 	aa_prob_donor = defaultdict(dict)
# 	aa_dr_probs = defaultdict(dict)
# 	aa_dr_mm_probs = defaultdict(dict)

# 	probs = defaultdict(dict)
# 	prob_check=defaultdict(dict)

# 	#Dictionaries to calculate AA-MM Probabilities
# 	all_pos_freqs = defaultdict(dict)
# 	pos_freqs = defaultdict(dict)
# 	pos_probs = defaultdict(dict)

# 	#Dictionaries to store D or R Genotype Frequencies
# 	geno_list_donor = defaultdict(dict)
# 	geno_list_recip = defaultdict(dict)

# 	#Dictionary to store D|R pair frequency
# 	dr_geno = defaultdict(dict)

# 	#Enumeration Dict
# 	showAAMM = defaultdict(dict)
# 	start_position = ard_start_pos[locus]
# 	end_position = ard_end_pos[locus]
	
# 	#calculate donor and recip genotype frequencies and create a genotype dictionary for each
# 	for da1 in dalleles1:
# 		for da2 in dalleles2:
# 			da = (da1)+ '+' + (da2)
# 			if (da1 == da2):
# 				df1 = dalleles1.get(da1)
# 				gfreq = df1*df1
# 				if da not in geno_list_donor:
# 					geno_list_donor[da]=gfreq
# 				else:
# 					geno_list_donor[da]=geno_list_donor[da] + gfreq
# 			else:
# 				df1 = dalleles1.get(da1)
# 				df2 = dalleles2.get(da2)
# 				gfreq = 2*df1*df2
# 				if da not in geno_list_donor:
# 					geno_list_donor[da]=gfreq
# 				else:
# 					geno_list_donor[da]=geno_list_donor[da] + gfreq
# 	for ra1 in ralleles1:
# 		for ra2 in ralleles2:
# 			ra = (ra1) + '+' + (ra2)
# 			if (ra1 == ra2):
# 				rf1 = ralleles1.get(ra1)
# 				gfreq = rf1*rf1
# 				if ra not in geno_list_recip:
# 					geno_list_recip[ra]=gfreq
# 				else:
# 					geno_list_recip[ra]=geno_list_recip[ra] + gfreq			
# 			else:
# 				rf1 = ralleles1.get(ra1)
# 				rf2 = ralleles2.get(ra2)
# 				gfreq = 2*rf1*rf2
# 				if ra not in geno_list_recip:
# 					geno_list_recip[ra]=gfreq
# 				else:
# 					geno_list_recip[ra]=geno_list_recip[ra] + gfreq	

# 	#Get strings for donor and recip geno types, calculate pair frequency, and store for probability calculation
# 	for dgeno in geno_list_donor:
# 		da1,da2 = dgeno.split('+')
# 		dfgeno = geno_list_donor.get(dgeno)
# 		dstring1 = aa_mm.HLA_seq[da1].seq[start_position-1:end_position]
# 		dstring2 = aa_mm.HLA_seq[da2].seq[start_position-1:end_position]
# 		dstring1 = str(dstring1)
# 		dstring2 = str(dstring2)
# 		for rgeno in geno_list_recip:
# 			ra1,ra2 = rgeno.split('+')
# 			rfgeno = geno_list_recip.get(rgeno)
# 			rstring1 = aa_mm.HLA_seq[ra1].seq[start_position-1:end_position]
# 			rstring2 = aa_mm.HLA_seq[ra2].seq[start_position-1:end_position]
# 			combo = (dgeno) + '|' + (rgeno)
# 			rstring1 = str(rstring1)
# 			rstring2 = str(rstring2)

# 			drfreq = rfgeno*dfgeno
# 			#print("To calculate D|R probability of", combo , "multiply recipient frequency by donor frequency:", rfgeno, '*', dfgeno, '=', drfreq )
# 			if combo not in dr_geno:
# 				dr_geno[combo] = drfreq
# 			else:
# 				dr_geno[combo] = dr_geno[combo] + drfreq


# 			#based on locus check for MM at select positions and if there are store combo and freq in MM dictionary for probability calcs
# 			if (locus == "DRB1"):
# 				for pos in list(dr_fibers_pos):
# 					daa1 = dstring1[pos-1]
# 					daa2 = dstring2[pos-1]
# 					raa1 = rstring1[pos-1]
# 					raa2 = rstring2[pos-1]
# 					daa = daa1 + daa2
# 					#print(daa)
# 					daa = ''.join(sorted(daa, key=str.lower))
# 					#print(daa)
# 					raa = raa1 + raa2
# 					raa = ''.join(sorted(raa, key=str.lower))
# 					#print(raa , daa)
# 						#print(geno_list)
# 					show = raa + '|'+ daa
# 					if raa not in aa_geno_recip[pos]:
# 						aa_geno_recip[pos][raa]=rfgeno
# 					else:
# 						aa_geno_recip[pos][raa]=aa_geno_recip[pos][raa]+rfgeno
# 					if daa not in aa_geno_donor[pos]:
# 						aa_geno_donor[pos][daa]=dfgeno
# 					else:
# 						aa_geno_donor[pos][daa]=aa_geno_donor[pos][daa]+dfgeno

# 					draafreq = rfgeno*dfgeno
# 					if pos not in all_pos_freqs:
# 						all_pos_freqs[pos]= draafreq
# 					else: 
# 						all_pos_freqs[pos]=all_pos_freqs[pos]+draafreq
# 					if(raa == daa):
# 						#print("yes:", raa,daa)
# 						continue
# 					else:
# 						showAAMM[show]=pos
# 						if pos not in pos_freqs:
# 							pos_freqs[pos]= draafreq
# 						else: 
# 							pos_freqs[pos]=pos_freqs[pos]+draafreq
# 						if combo not in probs:
# 							probs[combo]=drfreq
# 						else:
# 							continue

# 			if (locus == "DQB1"):
# 				for pos in list(dq_fibers_pos):
# 					daa1 = dstring1[pos-1]
# 					daa2 = dstring2[pos-1]
# 					raa1 = rstring1[pos-1]
# 					raa2 = rstring2[pos-1]
# 					daa = daa1 + daa2
# 					#print(daa)
# 					daa = ''.join(sorted(daa, key=str.lower))
# 					#print(daa)
# 					raa = raa1 + raa2
# 					raa = ''.join(sorted(raa, key=str.lower))
# 					#print(raa , daa)
# 						#print(geno_list)
# 					if(raa == daa):
# 						#print("yes:", raa,daa)
# 						continue
# 					else:
# 						showAAMM[show]=pos
# 						if pos not in pos_freqs:
# 							pos_freqs[pos]= draafreq
# 						else: 
# 							pos_freqs[pos]=pos_freqs[pos]+draafreq
# 						if combo not in probs:
# 							probs[combo]=drfreq
# 						else:
# 							continue
				

# 	#get probability of MM from summation of MM dict diveded by summation of all genotype freqs dict
# 	print("Loci analyzed for High Risk AA-MM Pos:", locus)
# 	print("Get a dictionary of Donor genotype frequencys:", dict(islice(geno_list_donor.items(), 0, 4)))
# 	print("Get a dictionary of Recipient genotype frequencys:", dict(islice(geno_list_recip.items(), 0, 4)))
# 	print("Probabilitys of D|R pair:", dict(islice(dr_geno.items(), 0, 4)))
# 	print("Probabilitys of D|R pair with AAMMs identified as HighRisk:", dict(islice(probs.items(), 0, 4)))
# 	print("Get a dictionary of AAMMs identified as HighRisk:", dict(islice(showAAMM.items(), 0, 4)))
# 	print("Get a dictionary of frequencys for AAMMs identified as HighRisk:", dict(islice(pos_freqs.items(), 0, 4)))
# 	sumgeno = sum(dr_geno.values())
# 	sumpossible =sum(probs.values())

# 	for geno in probs:
# 		possible_geno = probs.get(geno)
# 		possible_prob = possible_geno/sumgeno
# 		#print("Probability of Specific D|R Pair Mismatching:", geno , "-", possible_geno, "/",sumpossible, "=", possible_prob)
# 		prob_check[geno]=possible_prob
# 	expected_prob =sum(prob_check.values())
# 	#print("Store all D|R genotype MM probability combinations to check calculated >=1AAMM probability:", prob_check)
# 	print("Sum the dictionary to find the overall expected probability for >=1AAMM:", expected_prob)

# 	print("Take the sum of the D|R frequencies that will MM:", sumpossible)
# 	print("And divide by the sum of all D|R frequencies:", sumgeno)
# 	mm_prob = sumpossible/sumgeno
# 	print("To get the probability of >=1AAMM:",mm_prob)

# 	print("Store all AA assignments and frequencies for Recip genotypes to calculate AA-MM pos probs:", aa_geno_recip)
# 	print("Store all AA assignments and frequencies  for Donors genotypes to calculate AA-MM pos probs:", aa_geno_donor)

# 	for pos in aa_geno_recip:
# 		aa_list = aa_geno_recip.get(pos)
# 		sumgenopos =sum(aa_list.values())
# 		#print(aa_list)
# 		print("To show AA-MM prob calculations of recipient for position:", pos)
# 		for aaR in aa_list:
# 			sumpos = aa_list.get(aaR)
# 			print("Take the AA assignment frequency at the position:", sumpos)
# 			print("Divide by the sum of the all AA assignment frequencies at the position:", sumgenopos)
# 			pos_prob = sumpos/sumgenopos
# 			print("To get the probability of the specific AA assignment:", pos_prob)
# 			aa_prob_recip[pos][aaR]=pos_prob
# 	print("Store all Recip AA assignment probs in a dict to calculate AA-MM positional probs between D|R:", aa_prob_recip)

# 	for pos in aa_geno_donor:
# 		aa_list = aa_geno_donor.get(pos)
# 		sumgenopos =sum(aa_list.values())
# 		#print(aa_list)
# 		for aaD in aa_list:
# 			sumpos = aa_list.get(aaD)
# 			#print("Take the AA assignment frequency at the position:", sumpos)
# 			#print("Divide by the sum of the all AA assignment frequencies at the position:", sumgenopos)
# 			pos_prob = sumpos/sumgenopos
# 			#print("To get the probability of the specific AA assignment:", pos_prob)
# 			aa_prob_donor[pos][aaD]=pos_prob
# 	print("Store all Donor AA assignment probs in a dict to calculate AA-MM positional probs between D|R:", aa_prob_donor)

# 	for pos in dr_fibers_pos:
# 		print("Extract AA-MM probs from aa_prob_donor and aa_prob_recip for position:", pos)
# 		raa_list = aa_prob_recip.get(pos)
# 		daa_list = aa_prob_donor.get(pos)
# 		print(raa_list)
# 		print(daa_list)

# 		for aaR in raa_list:
# 			rprob = raa_list.get(aaR)
# 			for aaD in daa_list:
# 				show = aaD + '|'+ aaR
# 				dprob = daa_list.get(aaD)
# 				drprob = rprob * dprob
# 				aa_dr_probs[pos][show]=drprob
#				print("Calculate AA D|R assighnment", show, "probabilitys:", dprob, '*',rprob, '=',drprob)
# 				if (aaD == aaR):
# 					continue
# 				else:
# 					aa_dr_mm_probs[show]=drprob
# 	print("Store all D|R AA asssignment probs:", aa_dr_probs)
# 	print("Store all D|R AA-MM asssignment probs:", aa_dr_mm_probs)
# 	expected =sum(aa_dr_mm_probs.values())
# 	print("Sum AA-MM probabilitys in aa_dr_mm_probs to get expected AA-MM prob of position 30:", expected)



# 	for pos in pos_freqs:
# 		print("Calculate AA-MM probability of pos:", pos)
# 		sumpos = pos_freqs.get(pos)
# 		sumgenopos =all_pos_freqs.get(pos)
# 		print("Take the sum of D|R probs that will MM at the position:", sumpos)
# 		print("Divide by the sum of all D|R probs at the position:", sumgenopos)
# 		pos_prob = sumpos/sumgenopos
# 		print("To get the probability of the specific AAMM:", pos_prob)
# 		pos_probs[pos]=pos_prob
# 	print("Store all AAMM probs in a dict to be a return value of the function:", pos_probs)

# 	return mm_prob, pos_probs

drloc = "DRB1"
drfprob = getAAgenostringmatchFIBERSE(ddr1alleles,ddr2alleles, rdr1alleles, rdr2alleles, drloc)
# Out:
# Loci analyzed for High Risk AA-MM Pos: DRB1
# Get a dictionary of Donor genotype frequencys: {'DRB1*13:01+DRB1*13:01': 0.0032542737959813627, 'DRB1*13:01+DRB1*13:02': 0.008000741017374314, 'DRB1*13:01+DRB1*13:03': 0.0038349753375785814, 'DRB1*13:01+DRB1*13:04': 0.0014753747427636381}
# Get a dictionary of Recipient genotype frequencys: {'DRB1*13:01+DRB1*13:01': 0.003475187981769527, 'DRB1*13:01+DRB1*13:02': 0.005372481567252224, 'DRB1*13:01+DRB1*13:03': 0.0013461806642193987, 'DRB1*13:01+DRB1*13:04': 1.3080680961348868e-05}
# Probabilitys of D|R pair: {'DRB1*13:01+DRB1*13:01|DRB1*13:01+DRB1*13:01': 1.130921318518193e-05, 'DRB1*13:01+DRB1*13:01|DRB1*13:01+DRB1*13:02': 1.7483525983701796e-05, 'DRB1*13:01+DRB1*13:01|DRB1*13:01+DRB1*13:03': 4.380840460225974e-06, 'DRB1*13:01+DRB1*13:01|DRB1*13:01+DRB1*13:04': 4.2568117286109924e-08}
# Probabilitys of D|R pair with AAMMs identified as HighRisk: {'DRB1*13:01+DRB1*13:01|DRB1*13:01+DRB1*13:15': 1.1565339524690058e-08, 'DRB1*13:01+DRB1*13:01|DRB1*13:01+DRB1*13:19': 4.974993183770168e-09, 'DRB1*13:01+DRB1*13:01|DRB1*13:01+DRB1*13:26': 5.436426577333762e-10, 'DRB1*13:01+DRB1*13:01|DRB1*13:01+DRB1*13:41': 2.394298673356212e-10}
# Get a dictionary of AAMMs identified as HighRisk: {'DE|DD': 28, 'FY|FF': 26, 'GS|SS': 13, 'HY|YY': 30}
# Get a dictionary of frequencys for AAMMs identified as HighRisk: {28: 6.012371357465222e-05, 26: 1.252961714319658e-07, 13: 5.397170146127095e-05, 30: 1.169412240699267e-07}
# Sum the dictionary to find the overall expected probability for >=1AAMM: 0.04487959944032572
# Take the sum of the D|R frequencies that will MM: 0.00011340447197036864
# And divide by the sum of all D|R frequencies: 0.0025268601632917414
# To get the probability of >=1AAMM: 0.04487959944037291
# Store all AA assignments and frequencies for Recip genotypes to calculate AA-MM pos probs: defaultdict(<class 'dict'>, {9: {'EE': 21.753433489917573}, 10: {'YY': 21.753433489917573}, 11: {'SS': 21.753433489917573}, 12: {'TT': 21.753433489917573}, 13: {'SS': 21.44542986064272, 'GS': 0.30752148253191697, 'GG': 0.0004821467352346894}, 26: {'FF': 21.753219793518223, 'FY': 0.00021369617451058655, 'YY': 2.2430174993987956e-10}, 28: {'DD': 21.485104871680853, 'DE': 0.267760932235233, 'EE': 0.0005676859949726916}, 30: {'YY': 21.7524267570648, 'HY': 0.001006727874230368, 'HH': 4.978252117395893e-09}})
# Store all AA assignments and frequencies  for Donors genotypes to calculate AA-MM pos probs: defaultdict(<class 'dict'>, {9: {'EE': 282.6848872513769}, 10: {'YY': 282.67177172896874, 'QY': 0.013115456114237277, 'QQ': 6.631298180998329e-08}, 11: {'SS': 282.67177172896874, 'SV': 0.013115456114237277, 'VV': 6.631298180998329e-08}, 12: {'TT': 282.67177172896874, 'KT': 0.013115456114237277, 'KK': 6.631298180998329e-08}, 13: {'SS': 280.59040346587165, 'GS': 2.0796688624928, 'HS': 0.013073260352906573, 'GG': 0.001699401453754008, 'GH': 4.2195761340665694e-05, 'HH': 6.631298180998329e-08}, 26: {'FF': 282.67364687314944, 'FY': 0.011240329716947555, 'YY': 4.870654786004803e-08}, 28: {'DD': 279.36386946897164, 'DE': 3.315599883690419, 'EE': 0.005417899662024991}, 30: {'YY': 282.6848872513769}})
# To show AA-MM prob calculations of recipient for position: 9
# Take the AA assignment frequency at the position: 21.753433489917573
# Divide by the sum of the all AA assignment frequencies at the position: 21.753433489917573
# To get the probability of the specific AA assignment: 1.0
# To show AA-MM prob calculations of recipient for position: 10
# Take the AA assignment frequency at the position: 21.753433489917573
# Divide by the sum of the all AA assignment frequencies at the position: 21.753433489917573
# To get the probability of the specific AA assignment: 1.0
# To show AA-MM prob calculations of recipient for position: 11
# Take the AA assignment frequency at the position: 21.753433489917573
# Divide by the sum of the all AA assignment frequencies at the position: 21.753433489917573
# To get the probability of the specific AA assignment: 1.0
# To show AA-MM prob calculations of recipient for position: 12
# Take the AA assignment frequency at the position: 21.753433489917573
# Divide by the sum of the all AA assignment frequencies at the position: 21.753433489917573
# To get the probability of the specific AA assignment: 1.0
# To show AA-MM prob calculations of recipient for position: 13
# Take the AA assignment frequency at the position: 21.44542986064272
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348990987
# To get the probability of the specific AA assignment: 0.9858411487358988
# Take the AA assignment frequency at the position: 0.30752148253191697
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348990987
# To get the probability of the specific AA assignment: 0.01413668709698439
# Take the AA assignment frequency at the position: 0.0004821467352346894
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348990987
# To get the probability of the specific AA assignment: 2.216416711680612e-05
# To show AA-MM prob calculations of recipient for position: 26
# Take the AA assignment frequency at the position: 21.753219793518223
# Divide by the sum of the all AA assignment frequencies at the position: 21.753433489917036
# To get the probability of the specific AA assignment: 0.9999901764289801
# Take the AA assignment frequency at the position: 0.00021369617451058655
# Divide by the sum of the all AA assignment frequencies at the position: 21.753433489917036
# To get the probability of the specific AA assignment: 9.823560708687075e-06
# Take the AA assignment frequency at the position: 2.2430174993987956e-10
# Divide by the sum of the all AA assignment frequencies at the position: 21.753433489917036
# To get the probability of the specific AA assignment: 1.0311096408934524e-11
# To show AA-MM prob calculations of recipient for position: 28
# Take the AA assignment frequency at the position: 21.485104871680853
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348991106
# To get the probability of the specific AA assignment: 0.9876649992584089
# Take the AA assignment frequency at the position: 0.267760932235233
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348991106
# To get the probability of the specific AA assignment: 0.012308904355692485
# Take the AA assignment frequency at the position: 0.0005676859949726916
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348991106
# To get the probability of the specific AA assignment: 2.6096385898620397e-05
# To show AA-MM prob calculations of recipient for position: 30
# Take the AA assignment frequency at the position: 21.7524267570648
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348991728
# To get the probability of the specific AA assignment: 0.9999537207377884
# Take the AA assignment frequency at the position: 0.001006727874230368
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348991728
# To get the probability of the specific AA assignment: 4.6279033362571774e-05
# Take the AA assignment frequency at the position: 4.978252117395893e-09
# Divide by the sum of the all AA assignment frequencies at the position: 21.75343348991728
# To get the probability of the specific AA assignment: 2.2884902834779225e-10
# Store all Recip AA assignment probs in a dict to calculate AA-MM positional probs between D|R: defaultdict(<class 'dict'>, {9: {'EE': 1.0}, 10: {'YY': 1.0}, 11: {'SS': 1.0}, 12: {'TT': 1.0}, 13: {'SS': 0.9858411487358988, 'GS': 0.01413668709698439, 'GG': 2.216416711680612e-05}, 26: {'FF': 0.9999901764289801, 'FY': 9.823560708687075e-06, 'YY': 1.0311096408934524e-11}, 28: {'DD': 0.9876649992584089, 'DE': 0.012308904355692485, 'EE': 2.6096385898620397e-05}, 30: {'YY': 0.9999537207377884, 'HY': 4.6279033362571774e-05, 'HH': 2.2884902834779225e-10}})
# Store all Donor AA assignment probs in a dict to calculate AA-MM positional probs between D|R: defaultdict(<class 'dict'>, {9: {'EE': 1.0}, 10: {'YY': 0.9999536037368155, 'QY': 4.639602860188809e-05, 'QQ': 2.345826918968263e-10}, 11: {'SS': 0.9999536037368155, 'SV': 4.639602860188809e-05, 'VV': 2.345826918968263e-10}, 12: {'TT': 0.9999536037368155, 'KT': 4.639602860188809e-05, 'KK': 2.345826918968263e-10}, 13: {'SS': 0.9925907472212874, 'GS': 0.007356844869591737, 'HS': 4.62467607659586e-05, 'GG': 6.01164593647908e-06, 'GH': 1.4926783582531446e-07, 'HH': 2.345826918961214e-10}, 26: {'FF': 0.9999602370733972, 'FY': 3.976275430297171e-05, 'YY': 1.7229979406964924e-10}, 28: {'DD': 0.9882518736122313, 'DE': 0.011728960525331938, 'EE': 1.9165862436745626e-05}, 30: {'YY': 1.0}})
# Extract AA-MM probs from aa_prob_donor and aa_prob_recip for position: 9
# {'EE': 1.0}
# {'EE': 1.0}
# Calculate AA D|R assighnment EE|EE probabilitys: 1.0 * 1.0 = 1.0
# Extract AA-MM probs from aa_prob_donor and aa_prob_recip for position: 10
# {'YY': 1.0}
# {'YY': 0.9999536037368155, 'QY': 4.639602860188809e-05, 'QQ': 2.345826918968263e-10}
# Calculate AA D|R assighnment YY|YY probabilitys: 0.9999536037368155 * 1.0 = 0.9999536037368155
# Calculate AA D|R assighnment QY|YY probabilitys: 4.639602860188809e-05 * 1.0 = 4.639602860188809e-05
# Calculate AA D|R assighnment QQ|YY probabilitys: 2.345826918968263e-10 * 1.0 = 2.345826918968263e-10
# Extract AA-MM probs from aa_prob_donor and aa_prob_recip for position: 11
# {'SS': 1.0}
# {'SS': 0.9999536037368155, 'SV': 4.639602860188809e-05, 'VV': 2.345826918968263e-10}
# Calculate AA D|R assighnment SS|SS probabilitys: 0.9999536037368155 * 1.0 = 0.9999536037368155
# Calculate AA D|R assighnment SV|SS probabilitys: 4.639602860188809e-05 * 1.0 = 4.639602860188809e-05
# Calculate AA D|R assighnment VV|SS probabilitys: 2.345826918968263e-10 * 1.0 = 2.345826918968263e-10
# Extract AA-MM probs from aa_prob_donor and aa_prob_recip for position: 12
# {'TT': 1.0}
# {'TT': 0.9999536037368155, 'KT': 4.639602860188809e-05, 'KK': 2.345826918968263e-10}
# Calculate AA D|R assighnment TT|TT probabilitys: 0.9999536037368155 * 1.0 = 0.9999536037368155
# Calculate AA D|R assighnment KT|TT probabilitys: 4.639602860188809e-05 * 1.0 = 4.639602860188809e-05
# Calculate AA D|R assighnment KK|TT probabilitys: 2.345826918968263e-10 * 1.0 = 2.345826918968263e-10
# Extract AA-MM probs from aa_prob_donor and aa_prob_recip for position: 13
# {'SS': 0.9858411487358988, 'GS': 0.01413668709698439, 'GG': 2.216416711680612e-05}
# {'SS': 0.9925907472212874, 'GS': 0.007356844869591737, 'HS': 4.62467607659586e-05, 'GG': 6.01164593647908e-06, 'GH': 1.4926783582531446e-07, 'HH': 2.345826918961214e-10}
# Calculate AA D|R assighnment SS|SS probabilitys: 0.9925907472212874 * 0.9858411487358988 = 0.9785368024652581
# Calculate AA D|R assighnment GS|SS probabilitys: 0.007356844869591737 * 0.9858411487358988 = 0.0072526803973101215
# Calculate AA D|R assighnment HS|SS probabilitys: 4.62467607659586e-05 * 0.9858411487358988 = 4.559195975882692e-05
# Calculate AA D|R assighnment GG|SS probabilitys: 6.01164593647908e-06 * 0.9858411487358988 = 5.9265279358120345e-06
# Calculate AA D|R assighnment GH|SS probabilitys: 1.4926783582531446e-07 * 0.9858411487358988 = 1.4715437473934954e-07
# Calculate AA D|R assighnment HH|SS probabilitys: 2.345826918961214e-10 * 0.9858411487358988 = 2.3126127045243172e-10
# Calculate AA D|R assighnment SS|GS probabilitys: 0.9925907472212874 * 0.01413668709698439 = 0.014031944808829267
# Calculate AA D|R assighnment GS|GS probabilitys: 0.007356844869591737 * 0.01413668709698439 = 0.00010400141394247331
# Calculate AA D|R assighnment HS|GS probabilitys: 4.62467607659586e-05 * 0.01413668709698439 = 6.537759861974509e-07
# Calculate AA D|R assighnment GG|GS probabilitys: 6.01164593647908e-06 * 0.01413668709698439 = 8.498475754186244e-08
# Calculate AA D|R assighnment GH|GS probabilitys: 1.4926783582531446e-07 * 0.01413668709698439 = 2.110152688706507e-09
# Calculate AA D|R assighnment HH|GS probabilitys: 2.345826918961214e-10 * 0.01413668709698439 = 3.3162221137037637e-12
# Calculate AA D|R assighnment SS|GG probabilitys: 0.9925907472212874 * 2.216416711680612e-05 = 2.1999947200008075e-05
# Calculate AA D|R assighnment GS|GG probabilitys: 0.007356844869591737 * 2.216416711680612e-05 = 1.6305833914204898e-07
# Calculate AA D|R assighnment HS|GG probabilitys: 4.62467607659586e-05 * 2.216416711680612e-05 = 1.0250209342276592e-09
# Calculate AA D|R assighnment GG|GG probabilitys: 6.01164593647908e-06 * 2.216416711680612e-05 = 1.3324312518319076e-10
# Calculate AA D|R assighnment GH|GG probabilitys: 1.4926783582531446e-07 * 2.216416711680612e-05 = 3.3083972583962495e-12
# Calculate AA D|R assighnment HH|GG probabilitys: 2.345826918961214e-10 * 2.216416711680612e-05 = 5.1993299858958754e-15
# Extract AA-MM probs from aa_prob_donor and aa_prob_recip for position: 26
# {'FF': 0.9999901764289801, 'FY': 9.823560708687075e-06, 'YY': 1.0311096408934524e-11}
# {'FF': 0.9999602370733972, 'FY': 3.976275430297171e-05, 'YY': 1.7229979406964924e-10}
# Calculate AA D|R assighnment FF|FF probabilitys: 0.9999602370733972 * 0.9999901764289801 = 0.9999504138929913
# Calculate AA D|R assighnment FY|FF probabilitys: 3.976275430297171e-05 * 0.9999901764289801 = 3.976236369073087e-05
# Calculate AA D|R assighnment YY|FF probabilitys: 1.7229979406964924e-10 * 0.9999901764289801 = 1.7229810147038548e-10
# Calculate AA D|R assighnment FF|FY probabilitys: 0.9999602370733972 * 9.823560708687075e-06 = 9.823170095163637e-06
# Calculate AA D|R assighnment FY|FY probabilitys: 3.976275430297171e-05 * 9.823560708687075e-06 = 3.9061183083985084e-10
# Calculate AA D|R assighnment YY|FY probabilitys: 1.7229979406964924e-10 * 9.823560708687075e-06 = 1.6925974871374807e-15
# Calculate AA D|R assighnment FF|YY probabilitys: 0.9999602370733972 * 1.0311096408934524e-11 = 1.0310686409564822e-11
# Calculate AA D|R assighnment FY|YY probabilitys: 3.976275430297171e-05 * 1.0311096408934524e-11 = 4.099975931027174e-16
# Calculate AA D|R assighnment YY|YY probabilitys: 1.7229979406964924e-10 * 1.0311096408934524e-11 = 1.7765997878917184e-21
# Extract AA-MM probs from aa_prob_donor and aa_prob_recip for position: 28
# {'DD': 0.9876649992584089, 'DE': 0.012308904355692485, 'EE': 2.6096385898620397e-05}
# {'DD': 0.9882518736122313, 'DE': 0.011728960525331938, 'EE': 1.9165862436745626e-05}
# Calculate AA D|R assighnment DD|DD probabilitys: 0.9882518736122313 * 0.9876649992584089 = 0.9760617860183457
# Calculate AA D|R assighnment DE|DD probabilitys: 0.011728960525331938 * 0.9876649992584089 = 0.011584283788553876
# Calculate AA D|R assighnment EE|DD probabilitys: 1.9165862436745626e-05 * 0.9876649992584089 = 1.8929451509375136e-05
# Calculate AA D|R assighnment DD|DE probabilitys: 0.9882518736122313 * 0.012308904355692485 = 0.012164297791626854
# Calculate AA D|R assighnment DE|DE probabilitys: 0.011728960525331938 * 0.012308904355692485 = 0.0001443706532980035
# Calculate AA D|R assighnment EE|DE probabilitys: 1.9165862436745626e-05 * 0.012308904355692485 = 2.359107676282612e-07
# Calculate AA D|R assighnment DD|EE probabilitys: 0.9882518736122313 * 2.6096385898620397e-05 = 2.578980225881942e-05
# Store all D|R AA-MM asssignment probs: defaultdict(<class 'dict'>, {'QY|YY': 4.639602860188809e-05, 'QQ|YY': 2.345826918968263e-10, 'SV|SS': 4.639602860188809e-05, 'VV|SS': 2.345826918968263e-10, 'KT|TT': 4.639602860188809e-05, 'KK|TT': 2.345826918968263e-10, 'GS|SS': 0.0072526803973101215, 'HS|SS': 4.559195975882692e-05, 'GG|SS': 5.9265279358120345e-06, 'GH|SS': 1.4715437473934954e-07, 'HH|SS': 2.3126127045243172e-10, 'SS|GS': 0.014031944808829267, 'HS|GS': 6.537759861974509e-07, 'GG|GS': 8.498475754186244e-08, 'GH|GS': 2.110152688706507e-09, 'HH|GS': 3.3162221137037637e-12, 'SS|GG': 2.1999947200008075e-05, 'GS|GG': 1.6305833914204898e-07, 'HS|GG': 1.0250209342276592e-09, 'GH|GG': 3.3083972583962495e-12, 'HH|GG': 5.1993299858958754e-15, 'FY|FF': 3.976236369073087e-05, 'YY|FF': 1.7229810147038548e-10, 'FF|FY': 9.823170095163637e-06, 'YY|FY': 1.6925974871374807e-15, 'FF|YY': 1.0310686409564822e-11, 'FY|YY': 4.099975931027174e-16, 'DE|DD': 0.011584283788553876, 'EE|DD': 1.8929451509375136e-05, 'DD|DE': 0.012164297791626854, 'EE|DE': 2.359107676282612e-07, 'DD|EE': 2.578980225881942e-05, 'DE|EE': 3.0608348005874763e-07, 'YY|HY': 4.6279033362571774e-05, 'YY|HH': 2.2884902834779225e-10})
# Calculate AA-MM probability of pos: 28
# Take the sum of D|R probs that will MM at the position: 6.012371357465222e-05
# Divide by the sum of all D|R probs at the position: 0.0025268601632917414
# To get the probability of the specific AAMM: 0.023793842828377588
# Calculate AA-MM probability of pos: 26
# Take the sum of D|R probs that will MM at the position: 1.252961714319658e-07
# Divide by the sum of all D|R probs at the position: 0.0025268601632917414
# To get the probability of the specific AAMM: 4.958571639704132e-05
# Calculate AA-MM probability of pos: 13
# Take the sum of D|R probs that will MM at the position: 5.397170146127095e-05
# Divide by the sum of all D|R probs at the position: 0.0025268601632917414
# To get the probability of the specific AAMM: 0.02135919598770436
# Calculate AA-MM probability of pos: 30
# Take the sum of D|R probs that will MM at the position: 1.169412240699267e-07
# Divide by the sum of all D|R probs at the position: 0.0025268601632917414
# To get the probability of the specific AAMM: 4.627926221195689e-05
# Calculate AA-MM probability of pos: 10
# Take the sum of D|R probs that will MM at the position: 1.1723686916772456e-07
# Divide by the sum of all D|R probs at the position: 0.0025268601632917414
# To get the probability of the specific AAMM: 4.639626318497976e-05
# Calculate AA-MM probability of pos: 11
# Take the sum of D|R probs that will MM at the position: 1.1723686916772456e-07
# Divide by the sum of all D|R probs at the position: 0.0025268601632917414
# To get the probability of the specific AAMM: 4.639626318497976e-05
# Calculate AA-MM probability of pos: 12
# Take the sum of D|R probs that will MM at the position: 1.1723686916772456e-07
# Divide by the sum of all D|R probs at the position: 0.0025268601632917414
# To get the probability of the specific AAMM: 4.639626318497976e-05
# Store all AAMM probs in a dict to be a return value of the function: defaultdict(<class 'dict'>, {28: 0.023793842828377588, 26: 4.958571639704132e-05, 13: 0.02135919598770436, 30: 4.627926221195689e-05, 10: 4.639626318497976e-05, 11: 4.639626318497976e-05, 12: 4.639626318497976e-05})
